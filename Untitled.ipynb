# %%
# Import necessary liberaries
# %matplotlib inline
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.pipeline import Pipeline, FeatureUnion

# %%
def get_users_from_index(index):
    return df[df.index == index]['users'].values[0]
def get_index_from_users(users):
    return df[df.users == index]['users'].values[0]

# %%
# Read CSV files
post = pd.read_csv('posts.csv')
following = pd.read_csv('following.csv')
notification = pd.read_csv('notifications.csv')
user = pd.read_csv('users.csv')

# %%
# Drop unnecessary fields from the table
post = post.drop(columns = ["action","tags","slug","created_at","updated_at","image","status_id","post_id"])
post.head()
# Out:
#    id  user_id                              title  \
# 0   1     2077  What i have learnt so far on HTML
# 1   2     1719                   HTML BEGINS HERE
# 2   4     1310            My Laziness In The Open
# 3   6     1787                          MY TASK 2
# 4   7      167                             Task 2
#
#                                              content
# 0  I learnt how to use the table tag as i have us...
# 1   I am on this journey with start.ng, and here ...
# 2  I have not been attending classes on the HNG c...
# 3  My journey on **StartNG** pre-internship progr...
# 4   A Summary on The “idongesit.html” CV, Its Str...

# %%
# Drop unnecessary fields from the table
notification = notification.drop(columns = ['parent_comment_id','comment','sender_id','user_id','status','created_at','updated_at'])

# %%
notification
# Out:
#       id  post_id     action       type
# 0      1      NaN   Followed  Following
# 1      2      NaN   Followed  Following
# 2      3      NaN   Followed  Following
# 3      5      NaN   Followed  Following
# 4      7    278.0  Commented       Post
# ..   ...      ...        ...        ...
# 185  199    999.0       Like   Reaction
# 186  202   1007.0       Like   Reaction
# 187  216    998.0       Like   Reaction
# 188  219    999.0       Like   Reaction
# 189  222    998.0       Love   Reaction
#
# [190 rows x 4 columns]

# %%
#Merge table post and notification together
df = pd.merge(post, notification, on='id')

# %%
df.drop(columns = ['id'])
# Out:
#      user_id                                              title  \
# 0       2077                  What i have learnt so far on HTML
# 1       1719                                   HTML BEGINS HERE
# 2        167                                             Task 2
# 3        329                                 My Journey on HTML
# 4       2040                            StartNG HTML Exposition
# ..       ...                                                ...
# 135     2185                               the learning process
# 136      421                          My HNG Internship Journey
# 137      218        Zero To Hero In HTML: The Journey Continues
# 138     2208                 MY FIRST SOFTWARE DEVELOPMENT TASK
# 139     1413  Do not say how was your night, it's a wrong En...
#
#                                                content  post_id     action  \
# 0    I learnt how to use the table tag as i have us...      NaN   Followed
# ...

# %%
# Select importtant features
features = ['user_id','title','content','post_id','action','type']

# %%
def combine_features(row):
        return FeatureUnion(row['user_id'] +' '+row['title'] +' '+row['content'] +' '+row['post_id'] +' '+row['action'] +' '+row['type'])

# %%
combined_features = df["combined_features"] = df.apply(combine_features,axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-165-ce567eb32155> in <module>
# ----> 1 combined_features = combine_features.transform(features)
#
# AttributeError: 'function' object has no attribute 'transform'

# %%
cv = CountVectorizer()

# %%
count_matrix = cv.fit_transform(df["combined_features"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-a92fc4ca4350> in <module>
# ----> 1 count_matrix = cv.fit_transform(df["combined_features"])
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# ...
